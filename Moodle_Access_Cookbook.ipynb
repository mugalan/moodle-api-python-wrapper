# %% [markdown]
# <a href="https://colab.research.google.com/github/mugalan/moodle-api-python-wrapper/blob/main/Moodle_Access_Cookbook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Dependencies

# %%
import json
import pandas as pd
import numpy as np
import re
import time
from datetime import datetime
from pandas import to_datetime
#import plotly.figure_factory as ff
import plotly.graph_objects as go
import json
import plotly.express as px
import requests
import copy
import urllib
import pathlib
import os
from IPython.display import HTML, display
from IPython.core.display import HTML

# %% [markdown]
# #Orise-Webservice Client

# %% [markdown]
# #URL Specifications

# %%
# !pip install "git+https://github.com/mugalan/moodle-api-python-wrapper.git"

# %%
from moodle_api_python_wrapper import MgMoodle

# %%
DB_HOST="localhost"
DB_PORT="3306"
DB_NAME="xxx"
DB_USER="xxx"
DB_PASSWORD=


CRON_PORT=6383
#If Moodle is linked
MOODLE_KEY="xxxx"

# #Moodle DB credentials
moodle_db = {
    'moodle': {
        'NAME': DB_NAME,
        'USER': DB_USER,
        'PASSWORD': DB_PASSWORD,
        'HOST': DB_HOST,   # Set to the address of your MySQL server. 'localhost' is default.
        'PORT': DB_PORT,        # Default MySQL port
    }
}
#Moodle Webservice Access setup
moodleURL = "xxxx"
ENDPOINT="/webservice/rest/server.php"
moodleWebserviceAccessParams={'KEY':MOODLE_KEY,'URL':moodleURL,'ENDPOINT':ENDPOINT}

# %%
mgm=MgMoodle(moodleWebserviceAccessParams,moodle_db)

# %%
wsfunction='core_course_get_courses'
parameters=
mgm.call_moodle_webservice(wsfunction=wsfunction,parameters=parameters)

# %%
mgm.get_users_list()

# %%
mgm.get_user_courses(userid=239)

# %%
mgm.get_category_info()
